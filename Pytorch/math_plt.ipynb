# %%
import matplotlib.pyplot as plt
import math 
import random
#%matplotlib inline

m = []
n = []

for x in range(-10,10):
    y = 0.01 * math.cos(x)
    m.append(x)
    n.append(y)

x = 0 
o = []
p = []
while(x < 1):
#     x += math.exp(x)
    x += 0.0001
    y = 0.01 * math.cos(x)
    o.append(x)
    p.append(y)
    
plt.plot(m,n,c='red',label='test') #分别为x,y轴对应数据,c:color,label
plt.legend(loc='best')  # 显示label,loc为显示位置(best为系统认为最好的位置)
plt.show()

plt.plot(o,p,c='blue',label='test') #分别为x,y轴对应数据,c:color,label
plt.legend(loc='best')  # 显示label,loc为显示位置(best为系统认为最好的位置)
plt.show()

# %%
import random
import matplotlib.pyplot as plt
import math

m = []
n = []

for x in range(-10,10):
    y = x + random.random()
    m.append(x)
    n.append(y)
    
plt.plot(m,n,c='red',label='test') #分别为x,y轴对应数据,c:color,label
plt.legend(loc='best')  # 显示label,loc为显示位置(best为系统认为最好的位置)
plt.show()

o = []
p = []
for x in n:
    y = 0.01 * math.cos(x)
    o.append(y)

plt.plot(n,o,c='blue',label='cos') #分别为x,y轴对应数据,c:color,label
plt.legend(loc='best')  # 显示label,loc为显示位置(best为系统认为最好的位置)
plt.show()

# %%
import matplotlib.pyplot as plt
import math 
import random
#%matplotlib inline

m = []
n = []

for x in range(-10,10):
    y = 0.01 * math.cos(x)
    m.append(x)
    n.append(y)

x = 0 
o = []
p = []
while(x < 120):
#     x += math.exp(x)
    x += 0.1
    y = 0.01 * math.pow(0.98,x)
    if(x > 0.0001):
        o.append(x)
        p.append(y)
    
plt.plot(m,n,c='red',label='test') #分别为x,y轴对应数据,c:color,label
plt.legend(loc='best')  # 显示label,loc为显示位置(best为系统认为最好的位置)
plt.show()

plt.plot(o,p,c='blue',label='test') #分别为x,y轴对应数据,c:color,label
plt.legend(loc='best')  # 显示label,loc为显示位置(best为系统认为最好的位置)
plt.show()

# %%
import matplotlib.pyplot as plt
import math 
import random
#%matplotlib inline

m = []
n = []



x = 0 
o = []
p = []
while(x < 20):
    x += 1
    y = 0.001 * math.pow(0.9998,x)
    if(y > 0.0001):
        o.append(x)
        p.append(y)
    else:
        y = 0.01 * math.cos(x)
        print(y)
        p.append(y)

plt.plot(o,p,c='blue',label='test') #分别为x,y轴对应数据,c:color,label
plt.legend(loc='best')  # 显示label,loc为显示位置(best为系统认为最好的位置)
plt.show()

x = 0 
o = []
p = []
while(x < 200):
    x += 1
    y = math.pow(0.99999,x)
    o.append(x)
    p.append(y)

plt.plot(o,p,c='red',label='test') #分别为x,y轴对应数据,c:color,label
plt.legend(loc='best')  # 显示label,loc为显示位置(best为系统认为最好的位置)
plt.show()

# %%
import torch
import matplotlib.pyplot as plt
# %matplotlib inline
from torch.optim import *
import torch.nn as nn
import numpy as np 

class net(nn.Module):
    def __init__(self):
        super(net,self).__init__()
        self.fc = nn.Linear(1,10)
    def forward(self,x):
        return self.fc(x)

lr_list = []
model = net()
LR = 1
optimizer = Adam(model.parameters(),lr = LR)
lambda1 = lambda epoch:np.sin(epoch) / epoch
scheduler = lr_scheduler.LambdaLR(optimizer,lr_lambda = lambda1)
for epoch in range(100):
    scheduler.step()
    lr_list.append(optimizer.state_dict()['param_groups'][0]['lr'])
plt.plot(range(100),lr_list,color = 'r')

# %%
import math 
import matplotlib.pyplot as plt
#%matplotlib inline

x = 0 
o = []
p = []
while(x < 12000):
    x += 1
    y = 0.001 * math.pow(0.9998,x)
    o.append(x)
    p.append(y)

plt.plot(o,p,c='red',label='test') #分别为x,y轴对应数据,c:color,label
plt.legend(loc='best')  # 显示label,loc为显示位置(best为系统认为最好的位置)
plt.show()
